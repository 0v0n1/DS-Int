# %%
print ("hey")
# Out:
# hey

# %%
x, y, z= "orange", "banana", "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
x=y=z="Pen"
print(x)
print(y)
print(z)

# %%
#unpacking a list
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x="super"
def myfunc():
  print(f"Python is {x}")
myfunc()
# Out:
# Python is super

# %%
x=5
def myfunc():
    x=10
    print(x)
myfunc()
print(x)
# Out:
# 10
# 5

# %%
x="yo"
x=10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
#t=int("hey")
#print(t)
# Out:
# 1
# 2
# 3

# %%
x=str(1)
y=str(2.8)
z=str("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2.8
# 3

# %%
a="hey my name is avani singh chauhan"
print(a.split())
print(a[15:])
print(a[:-15])
print(a[-3:])
print(a[:3])
# Out:
# ['hey', 'my', 'name', 'is', 'avani', 'singh', 'chauhan']
# avani singh chauhan
# hey my name is avan
# han
# hey
